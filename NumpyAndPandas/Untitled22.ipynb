# %%
import sys
# !conda install --yes --prefix {sys.prefix} sqlalchemy
# Out:
# Fetching package metadata .............
# Solving package specifications: .
#
# Package plan for installation in environment C:\Users\user\.anaconda\Newfolder:
#
# The following packages will be UPDATED:
#
#     conda:          4.3.30-py36h7e176b0_0 --> 4.5.12-py36_0
#     conda-env:      2.6.0-h36134e3_1      --> 2.6.0-1
#     pycosat:        0.6.2-py36hf17546d_1  --> 0.6.3-py36hfa6e2cd_0
#     sqlalchemy:     1.1.13-py36h5948d12_0 --> 1.2.15-py36he774522_0
#     vc:             14-h2379b0c_2         --> 14.1-h0510ff6_4
#     vs2015_runtime: 14.0.25123-hd4c4e62_2 --> 14.15.26706-h3a45250_0
#
# conda-env-2.6.   0% |                              | ETA:  --:--:--   0.00  B/s
# conda-env-2.6. 100% |###############################| ETA:  0:00:00 180.63 kB/s
# conda-env-2.6. 100% |###############################| Time: 0:00:00  45.11 kB/s
#
# vs2015_runtime   0% |                              | ETA:  --:--:--   0.00  B/s
# ...

# %%
# !conda install --yes --prefix {sys.prefix}
