# %%
import pandas as pd
df=pd.read_csv("HistoricalQuotes.csv",parse_dates=["date"],index_col='date')
df.head(5)
# Out:
#              close    volume    open    high     low
# date
# 2019-01-03  142.19  91106840  143.98  145.72  142.00
# 2019-01-02  157.92  35637070  154.89  158.85  154.23
# 2019-01-01  157.74  34499390  158.53  159.36  156.48
# 2018-12-31  156.23  41740600  157.50  158.52  154.55
# 2018-12-30  156.15  51608850  155.84  156.77  150.07

# %%
df.index
# Out:
# DatetimeIndex(['2019-01-03', '2019-01-02', '2019-01-01', '2018-12-31',
#                '2018-12-30', '2018-12-29', '2018-12-28', '2018-12-27',
#                '2018-12-26', '2018-12-25', '2018-12-24', '2018-12-23',
#                '2018-12-22', '2018-12-21', '2018-12-20', '2018-12-19',
#                '2018-12-18', '2018-12-17', '2018-12-16', '2018-12-15',
#                '2018-12-14', '2018-12-13', '2018-12-12', '2018-12-11',
#                '2018-12-10', '2018-12-09', '2018-12-08', '2018-12-07',
#                '2018-12-06', '2018-12-05', '2018-12-04', '2018-12-03',
#                '2018-12-02', '2018-12-01', '2018-11-30', '2018-11-29',
#                '2018-11-28', '2018-11-27', '2018-11-26', '2018-11-25',
#                '2018-11-24', '2018-11-23', '2018-11-22', '2018-11-21',
#                '2018-11-20', '2018-11-19', '2018-11-18', '2018-11-17',
#                '2018-11-16', '2018-11-15', '2018-11-14', '2018-11-13',
# ...

# %%
df['2018-12'].close.mean()
# Out:
# 171.8429032258064

# %%
df['2018-12-05']
# Out:
#              close    volume   open   high     low
# date
# 2018-12-05  185.86  41626820  190.0  190.7  184.99

# %%
df['2018-12-07':'2018-12-01']
# Out:
#              close    volume    open      high       low
# date
# 2018-12-07  176.78  31096240  179.73  180.2700  176.5500
# 2018-12-06  176.98  67678680  178.37  181.4700  175.5100
# 2018-12-05  185.86  41626820  190.00  190.7000  184.9900
# 2018-12-04  193.53  36191330  190.50  194.9695  189.4600
# 2018-12-03  191.41  46271660  188.39  191.9700  186.9000
# 2018-12-02  186.80  60547340  193.90  194.4800  185.9300
# 2018-12-01  192.23  46725710  191.63  197.1800  191.4501

# %%
df.close.resample('M').mean()
# Out:
# date
# 2018-11-30    216.381034
# 2018-12-31    171.842903
# 2019-01-31    152.616667
# Freq: M, Name: close, dtype: float64

# %%
# %matplotlib inline
df.close.resample('W').mean().plot()

# %%
# %matplotlib inline
df.close.resample('m').mean().plot()

# %%
# %matplotlib inline
df.close.resample('sm').mean().plot()

# %%
# %matplotlib inline
df.close.resample('c').mean().plot()

# %%
# %matplotlib inline
df.close.resample('q').mean().plot()

# %%
# %matplotlib inline
df.close.resample('W').mean().plot(kind="bar")

# %%
df.close.plot()
